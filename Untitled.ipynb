# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\schraidera\Documents\Auto-OCR\receipts_count_6month.csv',sep=';')

# %%
pd.options.display.max_rows = 999

df.sort_values(by='n_receipts',ascending=False)[250:500]
# Out:
#                                ShopName  n_receipts
# 165431                        FOOD PLUS        2028
# 209517                           BEALES        2027
# 197295             WASABI SUSHI & BENTO        2010
# 199053                            DEBRA        2002
# 120026                      TIM HORTONS        1987
# 139453                        ONE BELOW        1968
# 49052                         TACO BELL        1958
# 64776            NOTCUTTS GARDEN CENTRE        1950
# 213561                     WDFG UK LTD.        1949
# 81416                              EAT.        1942
# 121361                BRACIA DELIKATESY        1928
# 70172                               LID        1926
# 89735                           WYNSORS        1904
# 90140                          CHOPSTIX        1899
# 116780                         FANTASIA        1893
# 47559                              QUIZ        1875
# 216826                 SUPER LINCS LTD.        1861
# ...
